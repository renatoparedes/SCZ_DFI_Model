# %%
from utils import (
    sig,
    sigfit,
    adj_rmse,
    TwoFlashesProcessingStrategy,
    TwoFlashesProcessingStrategy_Explore,
)

# %% [markdown]
# ## Experimental Data

# %%
import pandas as pd

# Load data
df = pd.read_csv("DFI_SPQ_Data.csv")
data = pd.melt(df, value_name="Flashes", var_name="Delay", id_vars=["ID", "Group"])
data["Flashes"] = (data["Flashes"] / 10) * 100

# Average data by group
avg_data = data.groupby(["Group", "Delay"])["Flashes"].aggregate(["mean"])
avg_data.reset_index(inplace=True)
avg_data.rename(columns={"mean": "Flashes (%)"}, inplace=True)
avg_data["Delay"] = avg_data.Delay.astype(float)

# Fit group data to sigmoid
for group in avg_data.groupby("Group"):
    if group[0] == "H-SPQ":
        group[1]["Fit"] = sig(
            x=group[1]["Delay"], a=14.6033, b=61.7941, c=86.2012, d=-27.569
        )
        df_hspq = group[1]
    elif group[0] == "L-SPQ":
        group[1]["Fit"] = sig(
            x=group[1]["Delay"], a=15.045, b=66.7106, c=59.806, d=-26.553
        )
        df_lspq = group[1]

dataset = pd.concat([df_hspq, df_lspq])
dataset.head()
# Out:
#    Group  Delay  Flashes (%)        Fit
# 0  H-SPQ  108.0    35.357143  33.884199
# 1  H-SPQ  120.0    30.357143  28.623599
# 2  H-SPQ  132.0    27.142857  24.465345
# 3  H-SPQ  144.0    18.928571  21.365804
# 4  H-SPQ  156.0    18.214286  19.155035

# %%
import seaborn as sns

sns.scatterplot(data=dataset, x="Delay", y="Flashes (%)", hue="Group")
sns.lineplot(data=dataset, x="Delay", y="Fit", hue="Group")
# Out:
# <Axes: xlabel='Delay', ylabel='Flashes (%)'>

# %%
# Data to fit
hspq_data = dataset.query("Group == 'H-SPQ'").sort_values(by=["Delay"])["Fit"].values
soas = dataset.query("Group == 'H-SPQ'").sort_values(by=["Delay"])["Delay"].values
sns.scatterplot(data=dataset.query("Group == 'H-SPQ'"), y="Fit", x="Delay")
# Out:
# <Axes: xlabel='Delay', ylabel='Fit'>

# %% [markdown]
# ## Fitting

# %%
from skneuromsi.neural import Paredes2025
from skneuromsi.sweep import ParameterSweep
from scipy.optimize import differential_evolution
import numpy as np


def two_flashes_job(ff_pruning):

    model = Paredes2025(
        time_range=(0, 500),
        neurons=30,
        position_range=(0, 30),
        tau=(6.560e00, 9.191e00, 1.200e02),
    )

    sp = ParameterSweep(
        model=model,
        target="auditory_soa",
        repeat=1,
        n_jobs=1,
        range=soas,
        processing_strategy=TwoFlashesProcessingStrategy(),
    )

    res = sp.run(
        auditory_intensity=2.325,
        visual_intensity=1.45,
        auditory_stim_n=2,
        visual_stim_n=1,
        auditory_duration=7,
        visual_duration=12,
        noise=False,
        lateral_excitation=0.5,
        lateral_inhibition=0.4,
        cross_modal_weight=1.036e-03,
        feedback_weight=6.231e-01,
        feedforward_weight=3.892e00,
        feedforward_pruning_threshold=ff_pruning,
    )

    return res


def hspq_cost(theta):

    exp_data = hspq_data
    model_data = two_flashes_job(ff_pruning=theta[0])
    cost = np.sum(np.square(np.divide(exp_data - model_data, exp_data)))

    return cost


bounds = [(0, 3.892e00)]

hspq_fit_res = differential_evolution(
    hspq_cost,
    bounds,
    disp=True,
    updating="deferred",
    workers=30,
    polish=False,
)
# Out:
# differential_evolution step 1: f(x)= 0.5329242148211178
# differential_evolution step 2: f(x)= 0.5329242148211178
# differential_evolution step 3: f(x)= 0.5329242148211178
# differential_evolution step 4: f(x)= 0.5329242148211178
# differential_evolution step 5: f(x)= 0.5329242148211178
# differential_evolution step 6: f(x)= 0.5329242148211178
# differential_evolution step 7: f(x)= 0.5329242148211178
# differential_evolution step 8: f(x)= 0.5329242148211178
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8619-4zxslfh8'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8624-a74pyvzk'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8615-kq5j0vsa'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8617-qt5guwqq'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8623-ouwpz2br'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8618-k0g2sme6'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8622-5dxblf38'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8616-g0suky5s'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8620-xoam34jh'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8625-7_pn0zwq'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8614-ixzam4qq'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-8621-yfdjuluc'}
#   warnings.warn(

# %%
print(hspq_fit_res)
# Out:
#              message: Optimization terminated successfully.
#              success: True
#                  fun: 0.5329242148211178
#                    x: [ 4.957e-01]
#                  nit: 8
#                 nfev: 135
#           population: [[ 4.957e-01]
#                        [ 3.044e-01]
#                        ...
#                        [ 1.886e-01]
#                        [ 3.142e-01]]
#  population_energies: [ 5.329e-01  5.329e-01 ...  5.329e-01  5.329e-01]

# %% [markdown]
# ## Exploration

# %%
from skneuromsi.neural import Paredes2025
from skneuromsi.sweep import ParameterSweep
import numpy as np


def two_flashes_job(ff_pruning):

    model = Paredes2025(
        time_range=(0, 500),
        neurons=30,
        position_range=(0, 30),
        tau=(6.560e00, 9.191e00, 1.200e02),
    )

    sp = ParameterSweep(
        model=model,
        target="auditory_soa",
        repeat=1,
        n_jobs=10,
        range=soas,
        processing_strategy=TwoFlashesProcessingStrategy_Explore(),
    )

    res = sp.run(
        auditory_intensity=2.325,
        visual_intensity=1.45,
        auditory_stim_n=2,
        visual_stim_n=1,
        auditory_duration=7,
        visual_duration=12,
        noise=False,
        lateral_excitation=0.5,
        lateral_inhibition=0.4,
        cross_modal_weight=1.036e-03,
        feedback_weight=6.231e-01,
        feedforward_weight=3.892e00,
        feedforward_pruning_threshold=ff_pruning,
    )

    return res


results_list, two_flashes_res, _ = two_flashes_job(ff_pruning=4.957e-01)
# Out:
# Sweeping 'auditory_soa':   0%|          | 0/15 [00:00<?, ?it/s]

# %%
sig_soas = np.linspace(soas[0], soas[-1], endpoint=True, num=100)
a, b, c, d = sigfit(soas, two_flashes_res)
print(a, b, c, d)
fb_model_data = sig(sig_soas, a, b, c, d)
# Out:
# 15.513976164320624 58.38269455067933 66.42383137626133 -23.217006345702153

# %%
import matplotlib.pyplot as plt

sns.scatterplot(x=soas, y=two_flashes_res, label="raw model")
sns.lineplot(x=sig_soas, y=fb_model_data, label="H-SPQ model")
sns.scatterplot(
    data=dataset.query("Group == 'H-SPQ'"), y="Fit", x="Delay", label="H-SPQ data"
)
plt.ylabel("Flashes", size=14)
plt.xlabel("SOA (ms)", size=14)
plt.show()

# %%
scz_error = adj_rmse(two_flashes_res, hspq_data, 1)
print(scz_error)
# Out:
# 7.935693288715376
