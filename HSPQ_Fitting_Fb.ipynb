# %%
from utils import (
    sig,
    sigfit,
    adj_rmse,
    TwoFlashesProcessingStrategy,
    TwoFlashesProcessingStrategy_Explore,
)

# %% [markdown]
# ## Experimental Data

# %%
import pandas as pd

# Load data
df = pd.read_csv("DFI_SPQ_Data.csv")
data = pd.melt(df, value_name="Flashes", var_name="Delay", id_vars=["ID", "Group"])
data["Flashes"] = (data["Flashes"] / 10) * 100

# Average data by group
avg_data = data.groupby(["Group", "Delay"])["Flashes"].aggregate(["mean"])
avg_data.reset_index(inplace=True)
avg_data.rename(columns={"mean": "Flashes (%)"}, inplace=True)
avg_data["Delay"] = avg_data.Delay.astype(float)

# Fit group data to sigmoid
for group in avg_data.groupby("Group"):
    if group[0] == "H-SPQ":
        group[1]["Fit"] = sig(
            x=group[1]["Delay"], a=14.6033, b=61.7941, c=86.2012, d=-27.569
        )
        df_hspq = group[1]
    elif group[0] == "L-SPQ":
        group[1]["Fit"] = sig(
            x=group[1]["Delay"], a=15.045, b=66.7106, c=59.806, d=-26.553
        )
        df_lspq = group[1]

dataset = pd.concat([df_hspq, df_lspq])
dataset.head()

## TODO double check fit values
# Out:
#    Group  Delay  Flashes (%)        Fit
# 0  H-SPQ  108.0    35.357143  33.884199
# 1  H-SPQ  120.0    30.357143  28.623599
# 2  H-SPQ  132.0    27.142857  24.465345
# 3  H-SPQ  144.0    18.928571  21.365804
# 4  H-SPQ  156.0    18.214286  19.155035

# %%
import seaborn as sns

sns.scatterplot(data=dataset, x="Delay", y="Flashes (%)", hue="Group")
sns.lineplot(data=dataset, x="Delay", y="Fit", hue="Group")
# Out:
# <Axes: xlabel='Delay', ylabel='Flashes (%)'>

# %%
# Data to fit
hspq_data = dataset.query("Group == 'H-SPQ'").sort_values(by=["Delay"])["Fit"].values
soas = dataset.query("Group == 'H-SPQ'").sort_values(by=["Delay"])["Delay"].values
sns.scatterplot(data=dataset.query("Group == 'H-SPQ'"), y="Fit", x="Delay")
# Out:
# <Axes: xlabel='Delay', ylabel='Fit'>

# %% [markdown]
# ## Fitting

# %%
from skneuromsi.neural import Paredes2022
from skneuromsi.sweep import ParameterSweep
from scipy.optimize import differential_evolution
import multiprocess as mp
import numpy as np


def two_flashes_job(fb_weight):

    model = Paredes2022(
        time_range=(0, 500),
        neurons=30,
        position_range=(0, 30),
        tau=(6.560e00, 9.191e00, 1.200e02),
    )

    sp = ParameterSweep(
        model=model,
        target="auditory_soa",
        repeat=1,
        n_jobs=1,
        range=soas,
        processing_strategy=TwoFlashesProcessingStrategy(),
    )

    res = sp.run(
        auditory_intensity=2.325,
        visual_intensity=1.45,
        auditory_stim_n=2,
        visual_stim_n=1,
        auditory_duration=7,
        visual_duration=12,
        noise=False,
        lateral_excitation=0.5,
        lateral_inhibition=0.4,
        cross_modal_weight=1.036e-03,
        feedback_weight=fb_weight,
        feedforward_weight=3.892e00,
    )

    return res


def hspq_cost(theta):

    exp_data = hspq_data
    model_data = two_flashes_job(fb_weight=theta[0])
    cost = np.sum(np.square(np.divide(exp_data - model_data, exp_data)))

    return cost


bounds = [(0.60, 0.64)]

with mp.Pool(12) as pool:
    hspq_fit_res = differential_evolution(
        hspq_cost,
        bounds,
        disp=True,
        updating="deferred",
        workers=pool.map,
        polish=False,
    )
# Out:
# differential_evolution step 1: f(x)= 0.3293406287123752
# differential_evolution step 2: f(x)= 0.3293406287123752
# differential_evolution step 3: f(x)= 0.29958439747337495
# differential_evolution step 4: f(x)= 0.29958439747337495
# differential_evolution step 5: f(x)= 0.2986227942814925
# differential_evolution step 6: f(x)= 0.2983550034066567
# differential_evolution step 7: f(x)= 0.2982556190254403
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4584-0ue45eb1'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4577-q2f401ur'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4578-6l1qqhsh'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4580-u7_mfsjh'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4576-2exej8d0'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4581-99vlwj7e'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4583-_6pwq3_l'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4586-orha3sqq'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4587-55bxu1ve'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4582-jz88fwy6'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4579-snzz3kwr'}
#   warnings.warn(
# /opt/homebrew/Cellar/python@3.13/3.13.1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/multiprocessing/resource_tracker.py:276: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown: {'/loky-4585-alrdgab1'}
#   warnings.warn(

# %%
print(hspq_fit_res)
# Out:
#              message: Optimization terminated successfully.
#              success: True
#                  fun: 0.2982556190254403
#                    x: [ 6.276e-01]
#                  nit: 7
#                 nfev: 120
#           population: [[ 6.276e-01]
#                        [ 6.276e-01]
#                        ...
#                        [ 6.275e-01]
#                        [ 6.276e-01]]
#  population_energies: [ 2.983e-01  2.984e-01 ...  2.989e-01  2.986e-01]

# %% [markdown]
# ## Exploration

# %%
from skneuromsi.neural import Paredes2022
from skneuromsi.sweep import ParameterSweep
from scipy.optimize import differential_evolution
import multiprocess as mp
import numpy as np


def two_flashes_job(fb_weight):

    model = Paredes2022(
        time_range=(0, 500),
        neurons=30,
        position_range=(0, 30),
        tau=(6.560e00, 9.191e00, 1.200e02),
    )

    sp = ParameterSweep(
        model=model,
        target="auditory_soa",
        repeat=1,
        n_jobs=10,
        range=soas,
        processing_strategy=TwoFlashesProcessingStrategy_Explore(),
    )

    res = sp.run(
        auditory_intensity=2.325,
        visual_intensity=1.45,
        auditory_stim_n=2,
        visual_stim_n=1,
        auditory_duration=7,
        visual_duration=12,
        noise=False,
        lateral_excitation=0.5,
        lateral_inhibition=0.4,
        cross_modal_weight=1.036e-03,
        feedback_weight=fb_weight,
        feedforward_weight=3.892e00,
    )

    return res


results_list, two_flashes_res, _ = two_flashes_job(fb_weight=6.276e-01)
# Out:
# Sweeping 'auditory_soa':   0%|          | 0/15 [00:00<?, ?it/s]

# %%
sig_soas = np.linspace(soas[0], soas[-1], endpoint=True, num=100)
a, b, c, d = sigfit(soas, two_flashes_res)
print(a, b, c, d)
fb_model_data = sig(sig_soas, a, b, c, d)
# Out:
# 18.158468259256377 52.80058952164569 71.48503570372644 -23.516095817110923

# %%
import matplotlib.pyplot as plt

sns.scatterplot(x=soas, y=two_flashes_res, label="raw model")
sns.lineplot(x=sig_soas, y=fb_model_data, label="H-SPQ model")
sns.scatterplot(
    data=dataset.query("Group == 'H-SPQ'"), y="Fit", x="Delay", label="H-SPQ data"
)
plt.ylabel("Flashes", size=14)
plt.xlabel("SOA (ms)", size=14)
plt.show()

# %%
scz_error = adj_rmse(two_flashes_res, hspq_data, 1)
print(scz_error)
# Out:
# 5.893958016067193
